# %%
print("Hello Python World!")
# Out:
# Hello Python World!

# %%
message = "Hello Python World!"
print(message)
message = "Hello Python Crash Course World"
print(message)
# Out:
# Hello Python World!
# Hello Python Crash Course World

# %% [markdown]
# TRY IT YOURSELF 1

# %%
my_message = "this is my 1 book and im solving its 1st question"
print(my_message)

my_2nd_message = "this is my second message"
print(my_2nd_message)
my_2nd_message = "this is my third message with same variable name"
print(my_2nd_message)
# Out:
# this is my 1 book and im solving its 1st question
# this is my second message
# this is my third message with same variable name

# %%
# 1st datatype strings
a = "this is a string."
b = 'this is also a string.'
c = 'I Told my friend, "python is my favourite language".'
d = "The Language 'Python' is named after Monty Python, not the snake."
e = "One of the python's strengths is its diverse and supportive community."
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# this is a string.
# this is also a string.
# I Told my friend, "python is my favourite language".
# The Language 'Python' is named after Monty Python, not the snake.
# One of the python's strengths is its diverse and supportive community.

# %%
name = 'ada lovelace'
print("Title Case : ",name.title())
print("Upper Case : ",name.upper())
print("Lower Case : ",name.lower())
# Out:
# Title Case :  Ada Lovelace
# Upper Case :  ADA LOVELACE
# Lower Case :  ada lovelace

# %%
# variable inside strings and f stands for format

first_name = "alexandra"
last_name = "Pratap Singh"
full_name = f"{first_name} {last_name}"
print(full_name)

print(f"Hello, {first_name.title()}")
print(f"Hello, {first_name.upper()}")
print(f"Hello, {first_name.lower()}")
# Out:
# alexandra Pratap Singh
# Hello, Alexandra
# Hello, ALEXANDRA
# Hello, alexandra

# %%
# \t and \n 

print('python')
print('\tpython')
# Out:
# python
# 	python

# %%
print('Languages:\n\tpython\n\tC\n\tJavaScript\n\tKotlin')
# Out:
# Languages:
# 	python
# 	C
# 	JavaScript
# 	Kotlin

# %%
# stripping whitespaces 

fav_language = 'python   '
fav_language.rstrip()
# Out:
# 'python'

# %%
fav_language = '   python'
fav_language.lstrip()
# Out:
# 'python'

# %%
fav_language = '           python            '
fav_language.strip()
# Out:
# 'python'

# %%
# removing prefixes

google_url = 'https://www.google.com'
google_url.removeprefix('https://')
# Out:
# 'www.google.com'

# %%
# removing suffixs

amazon_url = 'https://www.amazon.com'
amazon_url.removesuffix('www.amazon.com')
# Out:
# 'https://'

# %% [markdown]
# TRY IT YOURSELF 2

# %%
Name = 'Shiva'
Message = f'Hello {Name}, would you like to learn python today ?'
print(Message)
# Out:
# Hello Shiva, would you like to learn python today ?

# %%
print(Name.upper())
print(Name.title())
print(Name.lower())
# Out:
# SHIVA
# Shiva
# shiva

# %%
quote = 'Excellence is a continuous process and not an accident.'
author = 'A.P.J. Abdul Kalam'
print(f'{author} Once Said, "{quote}"')
# Out:
# A.P.J. Abdul Kalam Once Said, "Excellence is a continuous process and not an accident."

# %%
person_name = '\t  extra whitespace  \n'
person_name
# Out:
# '\t  extra whitespace  \n'

# %%
person_name.lstrip()
# Out:
# 'extra whitespace  \n'

# %%
person_name.rstrip()
# Out:
# '\t  extra whitespace'

# %%
person_name.strip()
# Out:
# 'extra whitespace'

# %%
file_extension = 'python_notes.txt'
file_extension.removesuffix('.txt')
# Out:
# 'python_notes'

# %% [markdown]
# :-----      NUMBERS  -----------:

# %%
# 2nd datatype INTEGERS

print(2 + 3) # add
print(3 - 2) # sub
print(2 * 3) # multiply
print(3 / 3) # divide
print(3 ** 2) # power or exponent
print(3 ** 3) # power or exponent
print(3 ** 5) # power or exponent
# Out:
# 5
# 1
# 6
# 1.0
# 9
# 27
# 243

# %%
# order of calculation or BODMAS

print(2 + 3 * 4)

print((2 + 3) * 4)
# Out:
# 14
# 20

# %%
# floats
print(0.1 + 0.1)
print(0.2 + 0.2)
print(2 * 0.1)
print(2 * 0.2)
# Out:
# 0.2
# 0.4
# 0.2
# 0.4

# %%
0.2 + 0.1
# Out:
# 0.30000000000000004

# %%
3 * 0.1
# Out:
# 0.30000000000000004

# %%
4/2 # interger or whole number we get float
# Out:
# 2.0

# %%
# if we mix the integer and a float in any other operation youll get float

1 + 2.0
# Out:
# 3.0

# %%
2 * 3.0
# Out:
# 6.0

# %%
3.0 ** 2
# Out:
# 9.0

# %%
# more readable big numbers we use _

universe_age = 14_00_000_000
print(universe_age)
# Out:
# 1400000000

# %%
# multiple assighnment

x,y,z = 1,2,3

# %%
# constant
# constant value never change throughout the life 
# we use all capital letters to denote constant

MAX_AGE = 60
MIN_AGE = 18
MAX_CONNECTIONS = 5000

# %% [markdown]
# TRY IT YOURSELF 3

# %%
print(3 + 5)
print(16 - 8)
print(4 * 2)
print(2 ** 3)
print(16 // 2)
# Out:
# 8
# 8
# 8
# 8
# 8

# %%
num = 400
print(f"here's is your number : {num}" )
# Out:
# here's is your number : 400

# %%
# comments

# this is comment denoted with hash 

# today date is april 1 2025 and time is 8:11

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
